# %%
#<table class="wikitable sortable jquery-tablesorter" style="width:100%; text-align:center;">
import pandas as pd
import numpy as np
import regex

# %%
dfs=pd.read_html("https://en.wikipedia.org/wiki/List_of_cities_in_India_by_population")
# df = pd.read_csv("cities of india.csv")
# df.head()

# %%
len(dfs)
# Out:
# 3

# %%
dfs1=dfs[0]
dfs1
# Out:
#      Rank            City Population(2011)[3] Population(2001)  \
# 0       1          Mumbai            12442373         11978450
# 1       2           Delhi            11007835          9879172
# 2       3       Bangalore             8425970          4301326
# 3       4       Hyderabad             6809970          3637483
# 4       5       Ahmedabad             5570585          3520085
# ..    ...             ...                 ...              ...
# 319   320          Tezpur              102505            83028
# 320   321   Jehanabad[35]              102456            81503
# 321   322  Aurangabad[36]              101520            79393
# 322   323         Gangtok              100286            29354
# 323   324   Vasco Da Gama              100000                ―
#
#     State or union territory
# 0                Maharashtra
# 1                      Delhi
# 2                  Karnataka
# 3                  Telangana
# 4                    Gujarat
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
dfs1.to_csv("cities of india.csv")

# %%
type(dfs1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dfs1)
# Out:
# pandas.core.frame.DataFrame

# %%
dfs1.rename(columns = {'City':'Cities', 'Population(2011)[3]':'Population(2011)','State or union territory':"State or Union Territory"}, inplace = True)

dfs1
# Out:
#      Rank                 Cities Population(2011) Population(2001)  \
# 0       1                 Mumbai         12442373         11978450
# 1       2                  Delhi         11007835          9879172
# 2       3              Bangalore          8425970          4301326
# 3       4              Hyderabad          6809970          3637483
# 4       5              Ahmedabad          5570585          3520085
# 5       6                Chennai          4681087          4343645
# 6       7                Kolkata          4486679          4572876
# 7       8                  Surat          4467797          2433835
# 8       9                   Pune          3115431          2538473
# 9      10                 Jaipur          3046163          2322575
# 10     11                Lucknow          2815601          2185927
# 11     12                 Kanpur          2767031          2551337
# 12     13                 Nagpur          2405665          2052066
# ...

# %%
All_Cities=dfs1
All_Cities
# Out:
#      Rank                 Cities Population(2011) Population(2001)  \
# 0       1                 Mumbai         12442373         11978450
# 1       2                  Delhi         11007835          9879172
# 2       3              Bangalore          8425970          4301326
# 3       4              Hyderabad          6809970          3637483
# 4       5              Ahmedabad          5570585          3520085
# 5       6                Chennai          4681087          4343645
# 6       7                Kolkata          4486679          4572876
# 7       8                  Surat          4467797          2433835
# 8       9                   Pune          3115431          2538473
# 9      10                 Jaipur          3046163          2322575
# 10     11                Lucknow          2815601          2185927
# 11     12                 Kanpur          2767031          2551337
# 12     13                 Nagpur          2405665          2052066
# ...

# %%
dfs1.drop('Rank', inplace=True, axis=1) 
dfs1
# Out:
#                     Cities Population(2011) Population(2001)  \
# 0                   Mumbai         12442373         11978450
# 1                    Delhi         11007835          9879172
# 2                Bangalore          8425970          4301326
# 3                Hyderabad          6809970          3637483
# 4                Ahmedabad          5570585          3520085
# 5                  Chennai          4681087          4343645
# 6                  Kolkata          4486679          4572876
# 7                    Surat          4467797          2433835
# 8                     Pune          3115431          2538473
# 9                   Jaipur          3046163          2322575
# 10                 Lucknow          2815601          2185927
# 11                  Kanpur          2767031          2551337
# 12                  Nagpur          2405665          2052066
# 13                  Indore          1960631          1474968
# ...

# %%
# dfs1['Population(2001)'] = dfs1['Population(2001)'].replace({'_': ''}, regex=True)
# print(dfs1)

# %%
dfs1.index
# Out:
# RangeIndex(start=0, stop=324, step=1)

# %%
dfs1.index +=1
dfs1.index
# Out:
# RangeIndex(start=1, stop=325, step=1)

# %%
dfs1.head()
# Out:
#       Cities Population(2011) Population(2001) State or Union Territory
# 1     Mumbai         12442373         11978450              Maharashtra
# 2      Delhi         11007835          9879172                    Delhi
# 3  Bangalore          8425970          4301326                Karnataka
# 4  Hyderabad          6809970          3637483                Telangana
# 5  Ahmedabad          5570585          3520085                  Gujarat

# %%
dfs1["Population(2001)"]=dfs1["Population(2001)"].str.replace(r'\W',"unknown")
dfs1
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2291681525.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   dfs1["Population(2001)"]=dfs1["Population(2001)"].str.replace(r'\W',"unknown")
#                     Cities Population(2011) Population(2001)  \
# 1                   Mumbai         12442373         11978450
# 2                    Delhi         11007835          9879172
# 3                Bangalore          8425970          4301326
# 4                Hyderabad          6809970          3637483
# 5                Ahmedabad          5570585          3520085
# 6                  Chennai          4681087          4343645
# 7                  Kolkata          4486679          4572876
# 8                    Surat          4467797          2433835
# 9                     Pune          3115431          2538473
# 10                  Jaipur          3046163          2322575
# ...

# %%
dfs1["Population(2001)"].describe()
# Out:
# count         324
# unique        298
# top       unknown
# freq           24
# Name: Population(2001), dtype: object

# %%
pd.value_counts(dfs1["Population(2001)"])
# Out:
# unknown     24
# 271811       2
# 296662       2
# 228175       2
# 11978450     1
# 208179       1
# 176425       1
# 215314       1
# 166125       1
# 148549       1
# 210713       1
# 184937       1
# 174324       1
# 175010       1
# 184105       1
# 236600       1
# 187641       1
# 207421       1
# 205053       1
# 202135       1
# 182478       1
# 187029       1
# 216058       1
# 164240       1
# 195985       1
# 196955       1
# 188761       1
# 193725       1
# 140925       1
# 188050       1
# 172877       1
# 144623       1
# 164221       1
# 189696       1
# 215303       1
# 206102       1
# 192913       1
# 185190       1
# 183274       1
# 220749       1
# 184904       1
# 235795       1
# 212657       1
# 225464       1
# 171687       1
# 153874       1
# 231515       1
# 190347       1
# 217256       1
# 228333       1
# 210476       1
# 257610       1
# 231672       1
# 228280       1
# 260906       1
# 267348       1
# 214974       1
# 232517       1
# ...

# %%
df1=dfs1[dfs1['Population(2001)']== "unknown"]
display(dfs1[dfs1['Population(2001)']== "unknown"])
# Out:
#                Cities Population(2011) Population(2001)  \
# 246  Khora, Ghaziabad           190400          unknown
# 271             Adoni           166537          unknown
# 272             Udupi           165401          unknown
# 276       Mahbubnagar           158000          unknown
# 281          Hindupur           151835          unknown
# 286           Giridih           143529          unknown
# 287        Bhimavaram           142280          unknown
# 288        Port Blair           140572          unknown
# 292       Madanapalle           135669          unknown
# 297          Guntakal           126270          unknown
# 298        Srikakulam           125939          unknown
# 300       Dharmavaram           121874          unknown
# 301       Medininagar           120325          unknown
# 302          Gudivada           118167          unknown
# 303          Phagwara           117966          unknown
# 304       Pudukkottai           117745          unknown
# ...

# %%
dfs1.to_csv("unknown population(2001).csv")

# %%
df2=dfs1[dfs1['Population(2001)']== '271811' ]
display(dfs1[dfs1['Population(2001)']=='271811'  ])
# Out:
#        Cities Population(2011) Population(2001) State or Union Territory
# 116  Gopalpur           404991           271811              West Bengal
# 117  Agartala           399688           271811                  Tripura

# %%
pd.value_counts(dfs1["State or Union Territory"])
# Out:
# Uttar Pradesh                     37
# Maharashtra                       32
# Andhra Pradesh                    31
# West Bengal                       30
# Bihar                             25
# Tamil Nadu                        22
# Madhya Pradesh                    18
# Karnataka                         16
# Gujarat                           14
# Rajasthan                         12
# Haryana                           11
# Jharkhand                         11
# Telangana                         10
# Assam                              8
# Delhi                              7
# Kerala                             7
# Punjab                             6
# Chhattisgarh                       6
# Odisha                             6
# Jammu and Kashmir                  3
# Puducherry                         2
# Uttarakhand                        2
# Tripura                            1
# Chandigarh                         1
# Mizoram                            1
# ...

# %%
len(dfs1['State or Union Territory'])# total number of cities
# Out:
# 324

# %%
State_or_Union_Territory_count = dfs1["State or Union Territory"].value_counts()
State_or_Union_Territory_count
# Out:
# Uttar Pradesh                     37
# Maharashtra                       32
# Andhra Pradesh                    31
# West Bengal                       30
# Bihar                             25
# Tamil Nadu                        22
# Madhya Pradesh                    18
# Karnataka                         16
# Gujarat                           14
# Rajasthan                         12
# Haryana                           11
# Jharkhand                         11
# Telangana                         10
# Assam                              8
# Delhi                              7
# Kerala                             7
# Punjab                             6
# Chhattisgarh                       6
# Odisha                             6
# Jammu and Kashmir                  3
# Puducherry                         2
# Uttarakhand                        2
# Tripura                            1
# Chandigarh                         1
# Mizoram                            1
# ...

# %%
len(State_or_Union_Territory_count)
# Out:
# 30

# %%
 dfs1.to_csv("Statewise cities count.csv")

# %%
df2=dfs1[dfs1['State or Union Territory']== 'Uttar Pradesh' ]
display(dfs1[dfs1["State or Union Territory"]=='Uttar Pradesh' ])
# Out:
#                Cities Population(2011) Population(2001)  \
# 11            Lucknow          2815601          2185927
# 12             Kanpur          2767031          2551337
# 21          Ghaziabad          1648643           968256
# 23               Agra          1585704          1275134
# 26             Meerut          1305429          1039405
# 30           Varanasi          1201815          1091918
# 36          Allahabad          1112544           975393
# 53           Bareilly           898167           718395
# 54            Aligarh           889810           672315
# 57          Moradabad           872575           669087
# 67         Saharanpur           703345           455754
# 68          Gorakhpur           671048           622701
# 71              Noida           642381           305058
# 75          Firozabad           603797           279102
# 90               Loni           512296           120945
# 92             Jhansi           507293           383644
# ...

# %%
df21=df2.drop('State or Union Territory', inplace=True, axis=1) 
df21
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\4070880256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df21=df2.drop('State or Union Territory', inplace=True, axis=1)

# %%
Uttar_Pradesh=df2
Uttar_Pradesh
# Out:
#                Cities Population(2011) Population(2001)
# 11            Lucknow          2815601          2185927
# 12             Kanpur          2767031          2551337
# 21          Ghaziabad          1648643           968256
# 23               Agra          1585704          1275134
# 26             Meerut          1305429          1039405
# 30           Varanasi          1201815          1091918
# 36          Allahabad          1112544           975393
# 53           Bareilly           898167           718395
# 54            Aligarh           889810           672315
# 57          Moradabad           872575           669087
# 67         Saharanpur           703345           455754
# 68          Gorakhpur           671048           622701
# 71              Noida           642381           305058
# 75          Firozabad           603797           279102
# 90               Loni           512296           120945
# 92             Jhansi           507293           383644
# ...

# %%
Uttar_Pradesh.index
# Out:
# Int64Index([ 11,  12,  21,  23,  26,  30,  36,  53,  54,  57,  67,  68,  71,
#              75,  90,  92, 119, 131, 139, 142, 170, 172, 176, 180, 193, 206,
#             209, 235, 244, 245, 246, 249, 250, 260, 264, 275, 315],
#            dtype='int64')

# %%
len(Uttar_Pradesh)
# Out:
# 37

# %%
mean_rank=(11+12+21+23+26+30+36+53+54+57+67+68+71+
             75+90+92+119+131+139+142+170+172+176+180+193+206+
            209+235+244+245+246+249+250+260+264+275+315)/37
Uttar_Pradesh_mean_rank=mean_rank
Uttar_Pradesh_mean_rank
# Out:
# 140.7027027027027

# %%
df3=dfs1[dfs1['State or Union Territory']== 'Maharashtra' ]
display(dfs1[dfs1["State or Union Territory"]=='Maharashtra' ])
# Out:
#                     Cities Population(2011) Population(2001)  \
# 1                   Mumbai         12442373         11978450
# 9                     Pune          3115431          2538473
# 13                  Nagpur          2405665          2052066
# 15                   Thane          1818872          1262551
# 18        Pimpri-Chinchwad          1727692          1012472
# 24                  Nashik          1486053          1077236
# 28         Kalyan-Dombivli          1247327          1193512
# 29             Vasai-Virar          1222390           693350
# 32              Aurangabad          1175116           873311
# 35             Navi Mumbai          1120547           704002
# 49                 Solapur           951558           872478
# 62          Mira-Bhayandar           814655           520388
# 63                 Jalgaon           798514           462280
# 66                Bhiwandi           711329           598741
# ...

# %%
df31=df3.drop('State or Union Territory', inplace=True, axis=1) 
df31
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2896687831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df31=df3.drop('State or Union Territory', inplace=True, axis=1)

# %%
Maharashtra=df3
Maharashtra
# Out:
#                     Cities Population(2011) Population(2001)
# 1                   Mumbai         12442373         11978450
# 9                     Pune          3115431          2538473
# 13                  Nagpur          2405665          2052066
# 15                   Thane          1818872          1262551
# 18        Pimpri-Chinchwad          1727692          1012472
# 24                  Nashik          1486053          1077236
# 28         Kalyan-Dombivli          1247327          1193512
# 29             Vasai-Virar          1222390           693350
# 32              Aurangabad          1175116           873311
# 35             Navi Mumbai          1120547           704002
# 49                 Solapur           951558           872478
# 62          Mira-Bhayandar           814655           520388
# 63                 Jalgaon           798514           462280
# 66                Bhiwandi           711329           598741
# ...

# %%
Maharashtra.index
# Out:
# Int64Index([  1,   9,  13,  15,  18,  24,  28,  29,  32,  35,  49,  62,  63,
#              66,  70,  83,  84,  86,  93,  95, 103, 122, 123, 130, 140, 144,
#             151, 161, 164, 181, 248, 261],
#            dtype='int64')

# %%
len(Maharashtra.index)
# Out:
# 32

# %%
mean_rank=(1+9+13+15+18+24+28+29+32+35+49+62+63+
             66+70+83+84+86+93+95+103+122+123+130+140+144+
            151+161+164+181+248+261)/32
Maharashtra_mean_rank=mean_rank
Maharashtra_mean_rank
# Out:
# 90.09375

# %%
df4=dfs1[dfs1['State or Union Territory']== 'Andhra Pradesh' ]
display(dfs1[dfs1["State or Union Territory"]=='Andhra Pradesh' ])
# Out:
#                   Cities Population(2011) Population(2001)  \
# 17      Visakhapatnam[4]          1730320          1345938
# 42            Vijayawada          1034358           851282
# 64            Guntur[13]           670073           514461
# 77       Nellore[14][15]           558548           378428
# 99           Kurnool[18]           484327           345987
# 101  Rajahmundry[19][20]           476873           315251
# 107             Kakinada           443028           325985
# 134           Kadapa[21]           344893           125725
# 135      Anantapuram[21]           340613           255134
# 165            Eluru[22]           283648           190347
# 178            Anantapur           261004           218808
# 199        Vijayanagaram           228025           174324
# 200               Tenali           225982           184937
# 227               Ongole           204746           150471
# 233              Nandyal           200516           152676
# ...

# %%
df41=df4.drop('State or Union Territory', inplace=True, axis=1) 
df41
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\1634104756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df41=df4.drop('State or Union Territory', inplace=True, axis=1)

# %%
Andhra_Pradesh=df4
Andhra_Pradesh
# Out:
#                   Cities Population(2011) Population(2001)
# 17      Visakhapatnam[4]          1730320          1345938
# 42            Vijayawada          1034358           851282
# 64            Guntur[13]           670073           514461
# 77       Nellore[14][15]           558548           378428
# 99           Kurnool[18]           484327           345987
# 101  Rajahmundry[19][20]           476873           315251
# 107             Kakinada           443028           325985
# 134           Kadapa[21]           344893           125725
# 135      Anantapuram[21]           340613           255134
# 165            Eluru[22]           283648           190347
# 178            Anantapur           261004           218808
# 199        Vijayanagaram           228025           174324
# 200               Tenali           225982           184937
# 227               Ongole           204746           150471
# 233              Nandyal           200516           152676
# ...

# %%
Andhra_Pradesh.index
# Out:
# Int64Index([ 17,  42,  64,  77,  99, 101, 107, 134, 135, 165, 178, 199, 200,
#             227, 233, 247, 268, 271, 274, 281, 287, 292, 297, 298, 300, 302,
#             306, 310, 316, 317, 318],
#            dtype='int64')

# %%
len(Andhra_Pradesh.index)
# Out:
# 31

# %%
mean_rank=(17+42+64+77+99+101+107+134+135+165+178+199+200+
            227+233+247+268+271+274+281+287+292+297+298+300+302+
            306+310+316+317+318)/31
Andhra_Pradesh_mean_rank=mean_rank
Andhra_Pradesh_mean_rank
# Out:
# 214.90322580645162

# %%
df5=dfs1[dfs1['State or Union Territory']== 'West Bengal' ]
display(dfs1[dfs1["State or Union Territory"]=='West Bengal' ])
# Out:
#               Cities Population(2011) Population(2001)  \
# 7            Kolkata          4486679          4572876
# 37            Howrah          1077075          1007532
# 80          Durgapur           566937           493405
# 81           Asansol           564491           475439
# 91          Siliguri           509709           472374
# 110       Maheshtala           429423           385266
# 111  Rajpur Sonarpur           423806           336707
# 113    South Dum Dum           410524           392444
# 116         Gopalpur           404991           271811
# 120         Bhatpara           390467           442385
# 121         Panihati           383522           348438
# 136        Kamarhati           336579           314507
# 148        Bardhaman           314638           285602
# 149            Kulti           313977           289903
# 158            Bally           291972           260906
# 166          Barasat           283443           231515
# ...

# %%
df51=df5.drop('State or Union Territory', inplace=True, axis=1) 
df51
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2256690138.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df51=df5.drop('State or Union Territory', inplace=True, axis=1)

# %%
West_Bengal=df5
West_Bengal
# Out:
#               Cities Population(2011) Population(2001)
# 7            Kolkata          4486679          4572876
# 37            Howrah          1077075          1007532
# 80          Durgapur           566937           493405
# 81           Asansol           564491           475439
# 91          Siliguri           509709           472374
# 110       Maheshtala           429423           385266
# 111  Rajpur Sonarpur           423806           336707
# 113    South Dum Dum           410524           392444
# 116         Gopalpur           404991           271811
# 120         Bhatpara           390467           442385
# 121         Panihati           383522           348438
# 136        Kamarhati           336579           314507
# 148        Bardhaman           314638           285602
# 149            Kulti           313977           289903
# 158            Bally           291972           260906
# 166          Barasat           283443           231515
# ...

# %%
West_Bengal.index
# Out:
# Int64Index([  7,  37,  80,  81,  91, 110, 111, 113, 116, 120, 121, 136, 148,
#             149, 158, 166, 182, 187, 207, 213, 215, 221, 226, 231, 239, 241,
#             254, 257, 265, 270],
#            dtype='int64')

# %%
len(West_Bengal.index)
# Out:
# 30

# %%
mean_rank=(7+37+80+81+91+110+111+113+116+120+121+136+148+
            149+158+166+182+187+207+213+215+221+226+231+239+241+
            254+257+265+270)/30
West_Bengal_mean_rank=mean_rank
West_Bengal_mean_rank
# Out:
# 165.06666666666666

# %%
df6=dfs1[dfs1['State or Union Territory']== 'Bihar' ]
display(dfs1[dfs1["State or Union Territory"]=='Bihar' ])
# Out:
#              Cities Population(2011) Population(2001) State or Union Territory
# 19            Patna          1684222          1366444                    Bihar
# 104            Gaya           463454           385432                    Bihar
# 118       Bhagalpur           398138           340767                    Bihar
# 129     Muzaffarpur           351838           305525                    Bihar
# 155    Bihar Sharif           296889           232071                    Bihar
# 157       Darbhanga           294116           267348                    Bihar
# 168      Purnia[23]           280547           171687                    Bihar
# 177           Arrah           261099           203380                    Bihar
# 184       Begusarai           251136            93378                    Bihar
# 218          Munger           213303           188050                    Bihar
# 229         Chhapra           202352            79190                    Bihar
# ...

# %%
df61=df6.drop('State or Union Territory', inplace=True, axis=1) 
df61
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\606070816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df61=df6.drop('State or Union Territory', inplace=True, axis=1)

# %%
Bihar=df6
Bihar
# Out:
#              Cities Population(2011) Population(2001)
# 19            Patna          1684222          1366444
# 104            Gaya           463454           385432
# 118       Bhagalpur           398138           340767
# 129     Muzaffarpur           351838           305525
# 155    Bihar Sharif           296889           232071
# 157       Darbhanga           294116           267348
# 168      Purnia[23]           280547           171687
# 177           Arrah           261099           203380
# 184       Begusarai           251136            93378
# 218          Munger           213303           188050
# 229         Chhapra           202352            79190
# 256         Danapur           182429           131176
# 273         Katihar           164937           115169
# 277     Saharsa[26]           155175           125167
# 284     Hajipur[27]           147688           119412
# 285     Sasaram[28]           147396           131172
# ...

# %%
Bihar.index
# Out:
# Int64Index([ 19, 104, 118, 129, 155, 157, 168, 177, 184, 218, 229, 256, 273,
#             277, 284, 285, 291, 293, 294, 299, 312, 314, 319, 321, 322],
#            dtype='int64')

# %%
len(Bihar.index)
# Out:
# 25

# %%
mean_rank=( 7+42+45+53+56+61+98+101+103+107+134+189+192+
            202+206+217+223+253+290+305+306+312)/25
Bihar_mean_rank=mean_rank
Bihar_mean_rank
# Out:
# 140.08

# %%
df6=dfs1[dfs1['State or Union Territory']== 'Tamil Nadu' ]
display(dfs1[dfs1["State or Union Territory"]=='Tamil Nadu' ])
# Out:
#                   Cities Population(2011) Population(2001)  \
# 6                Chennai          4681087          4343645
# 41            Coimbatore    1,050,721 [5]           930882
# 44               Madurai          1017865           928869
# 52   Tiruchirappalli[10]           916674           752066
# 55              Tiruppur           877778           344543
# 60                 Salem           831038           696760
# 97             Erode[17]           498129           173600
# 100             Ambattur           478134           310967
# 102          Tirunelveli           473637           411831
# 106                Karur           444506           158955
# 133                Avadi           344701           229403
# 188         Tiruvottiyur           248059           212281
# 191          Thoothukudi           237374           216058
# 201            Nagercoil           224849           208179
# 205            Thanjavur           222943           215314
# ...

# %%
df61=df6.drop('State or Union Territory', inplace=True, axis=1) 
df61
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\606070816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df61=df6.drop('State or Union Territory', inplace=True, axis=1)

# %%
Tamil_Nadu=df6
Tamil_Nadu
# Out:
#                   Cities Population(2011) Population(2001)
# 6                Chennai          4681087          4343645
# 41            Coimbatore    1,050,721 [5]           930882
# 44               Madurai          1017865           928869
# 52   Tiruchirappalli[10]           916674           752066
# 55              Tiruppur           877778           344543
# 60                 Salem           831038           696760
# 97             Erode[17]           498129           173600
# 100             Ambattur           478134           310967
# 102          Tirunelveli           473637           411831
# 106                Karur           444506           158955
# 133                Avadi           344701           229403
# 188         Tiruvottiyur           248059           212281
# 191          Thoothukudi           237374           216058
# 201            Nagercoil           224849           208179
# 205            Thanjavur           222943           215314
# ...

# %%
Tamil_Nadu.index
# Out:
# Int64Index([  6,  41,  44,  52,  55,  60,  97, 100, 102, 106, 133, 188, 191,
#             201, 205, 216, 222, 252, 289, 304, 305, 311],
#            dtype='int64')

# %%
len(Tamil_Nadu.index)
# Out:
# 22

# %%
mean_rank=(7+42+45+53+56+61+98+101+103+107+134+189+192+
            202+206+217+223+253+290+305+306+312)/22
Tamil_Nadu_mean_rank=mean_rank
Tamil_Nadu_mean_rank
# Out:
# 159.1818181818182

# %%
df7=dfs1[dfs1['State or Union Territory']== 'Madhya Pradesh' ]
display(dfs1[dfs1["State or Union Territory"]=='Madhya Pradesh' ])
# Out:
#         Cities Population(2011) Population(2001) State or Union Territory
# 14      Indore          1960631          1474968           Madhya Pradesh
# 16      Bhopal          1795648          1437354           Madhya Pradesh
# 39     Gwalior          1069276           827026           Madhya Pradesh
# 40    Jabalpur          1055525           932484           Madhya Pradesh
# 89      Ujjain           515215           430427           Madhya Pradesh
# 125      Sagar           370296           232133           Madhya Pradesh
# 160      Dewas           289438           231672           Madhya Pradesh
# 169      Satna           280248           225464           Madhya Pradesh
# 175     Ratlam           264810           222202           Madhya Pradesh
# 192       Rewa           235422           183274           Madhya Pradesh
# 208      Katni           221883           187029           Madhya Pradesh
# 210  Singrauli           220257           185190           Madhya Pradesh
# ...

# %%
df71=df7.drop('State or Union Territory', inplace=True, axis=1) 
df71
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\3981683594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df71=df7.drop('State or Union Territory', inplace=True, axis=1)

# %%
Madhya_Pradesh=df7
Madhya_Pradesh
# Out:
#         Cities Population(2011) Population(2001)
# 14      Indore          1960631          1474968
# 16      Bhopal          1795648          1437354
# 39     Gwalior          1069276           827026
# 40    Jabalpur          1055525           932484
# 89      Ujjain           515215           430427
# 125      Sagar           370296           232133
# 160      Dewas           289438           231672
# 169      Satna           280248           225464
# 175     Ratlam           264810           222202
# 192       Rewa           235422           183274
# 208      Katni           221883           187029
# 210  Singrauli           220257           185190
# 220  Burhanpur           210886           193725
# 232    Khandwa           200738           172242
# 234     Morena           200482           150959
# 237      Bhind           197585           153752
# 259       Guna           180935           137175
# 262   Shivpuri           179977           146892

# %%
Madhya_Pradesh.index
# Out:
# Int64Index([ 14,  16,  39,  40,  89, 125, 160, 169, 175, 192, 208, 210, 220,
#             232, 234, 237, 259, 262],
#            dtype='int64')

# %%
len(Madhya_Pradesh.index)
# Out:
# 18

# %%
mean_rank=(15+17+40+41+90+126+161+170+176+193+209+211+221+
            233+235+238+260+263)/18
Madhya_Pradesh_mean_rank=mean_rank
Madhya_Pradesh_mean_rank
# Out:
# 161.05555555555554

# %%
df8=dfs1[dfs1['State or Union Territory']== 'Karnataka' ]
display(dfs1[dfs1["State or Union Territory"]=='Karnataka' ])



# df.reset_index(level=0, inplace=True)
# df
# Out:
#               Cities Population(2011) Population(2001)  \
# 3          Bangalore          8425970          4301326
# 50     Hubli–Dharwad           943788           786195
# 51   Mysore[7][8][9]           920550           762408
# 87          Gulbarga           532031           422569
# 96         Mangalore           499486           399565
# 98           Belgaum           488292           399653
# 108       Davanagere           435128           364523
# 114          Bellary           409644           316766
# 141          Bijapur           326360           228175
# 143          Shimoga           322428           274352
# 152           Tumkur           305821           248929
# 194          Raichur           232456           207421
# 217            Bidar           214373           172877
# 224           Hospet           206167           164240
# 272            Udupi           165401          unknown
# 313       Gangavathi           105529            85459
#
# ...

# %%
df81=df8.drop('State or Union Territory', inplace=True, axis=1) 
df81
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\485206630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df81=df8.drop('State or Union Territory', inplace=True, axis=1)

# %%
Karnataka=df8
Karnataka
# Out:
#               Cities Population(2011) Population(2001)
# 3          Bangalore          8425970          4301326
# 50     Hubli–Dharwad           943788           786195
# 51   Mysore[7][8][9]           920550           762408
# 87          Gulbarga           532031           422569
# 96         Mangalore           499486           399565
# 98           Belgaum           488292           399653
# 108       Davanagere           435128           364523
# 114          Bellary           409644           316766
# 141          Bijapur           326360           228175
# 143          Shimoga           322428           274352
# 152           Tumkur           305821           248929
# 194          Raichur           232456           207421
# 217            Bidar           214373           172877
# 224           Hospet           206167           164240
# 272            Udupi           165401          unknown
# 313       Gangavathi           105529            85459

# %%
Karnataka.index
# Out:
# Int64Index([3, 50, 51, 87, 96, 98, 108, 114, 141, 143, 152, 194, 217, 224, 272,
#             313],
#            dtype='int64')

# %%
len(Karnataka.index)
# Out:
# 16

# %%
mean_rank=(4+51+52+88+97+99+109+115+142+144+153+195+218+225+273+
            314)/16
Karnataka_mean_rank=mean_rank
Karnataka_mean_rank
# Out:
# 142.4375

# %%
df9=dfs1[dfs1['State or Union Territory']== 'Gujarat' ]
display(dfs1[dfs1["State or Union Territory"]=='Gujarat' ])
# Out:
#                     Cities Population(2011) Population(2001)  \
# 5                Ahmedabad          5570585          3520085
# 8                    Surat          4467797          2433835
# 20                Vadodara          1670806          1306227
# 27                  Rajkot          1286678           967476
# 78               Bhavnagar           593768           511085
# 88                Jamnagar           529308           443518
# 145               Junagadh           320250           168686
# 186             Gandhidham           248705           166388
# 211                 Nadiad           218095           192913
# 223            Gandhinagar           206167           195985
# 236                  Anand           198282           130685
# 243                  Morbi           194947           145719
# 253                Mehsana           184991           141453
# 263  Surendranagar Dudhrej           177851           156161
#
#     State or Union Territory
# ...

# %%
df91=df9.drop('State or Union Territory', inplace=True, axis=1) 
df91
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\1554271898.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df91=df9.drop('State or Union Territory', inplace=True, axis=1)

# %%
Gujarat=df9
Gujarat
# Out:
#                     Cities Population(2011) Population(2001)
# 5                Ahmedabad          5570585          3520085
# 8                    Surat          4467797          2433835
# 20                Vadodara          1670806          1306227
# 27                  Rajkot          1286678           967476
# 78               Bhavnagar           593768           511085
# 88                Jamnagar           529308           443518
# 145               Junagadh           320250           168686
# 186             Gandhidham           248705           166388
# 211                 Nadiad           218095           192913
# 223            Gandhinagar           206167           195985
# 236                  Anand           198282           130685
# 243                  Morbi           194947           145719
# 253                Mehsana           184991           141453
# 263  Surendranagar Dudhrej           177851           156161

# %%
Gujarat.index
# Out:
# Int64Index([5, 8, 20, 27, 78, 88, 145, 186, 211, 223, 236, 243, 253, 263], dtype='int64')

# %%
len(Gujarat.index)
# Out:
# 14

# %%
mean_rank=(6+9+21+28+79+89+146+187+212+224+237+244+254+264)/14
Gujarat_mean_rank=mean_rank
Gujarat_mean_rank
# Out:
# 142.85714285714286

# %%
df10=dfs1[dfs1['State or Union Territory']== 'Rajasthan' ]
display(dfs1[dfs1["State or Union Territory"]=='Rajasthan' ])
# Out:
#              Cities Population(2011) Population(2001) State or Union Territory
# 10           Jaipur          3046163          2322575                Rajasthan
# 43          Jodhpur          1033918           851051                Rajasthan
# 46          Kota[6]          1001694           694316                Rajasthan
# 69          Bikaner           647804           529690                Rajasthan
# 85            Ajmer           542580           485575                Rajasthan
# 105         Udaipur           451735           389438                Rajasthan
# 127        Bhilwara           360009           280128                Rajasthan
# 147           Alwar           315310           260593                Rajasthan
# 183       Bharatpur           252109           204587                Rajasthan
# 190           Sikar           237579           184904                Rajasthan
# 195            Pali           229956           187641                Rajasthan
# ...

# %%
df101=df10.drop('State or Union Territory', inplace=True, axis=1) 
df101
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\4249277154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df101=df10.drop('State or Union Territory', inplace=True, axis=1)

# %%
Rajasthan=df10
df10
# Out:
#              Cities Population(2011) Population(2001)
# 10           Jaipur          3046163          2322575
# 43          Jodhpur          1033918           851051
# 46          Kota[6]          1001694           694316
# 69          Bikaner           647804           529690
# 85            Ajmer           542580           485575
# 105         Udaipur           451735           389438
# 127        Bhilwara           360009           280128
# 147           Alwar           315310           260593
# 183       Bharatpur           252109           204587
# 190           Sikar           237579           184904
# 195            Pali           229956           187641
# 202  Sri Ganganagar           224773           210713

# %%
Rajasthan.index
# Out:
# Int64Index([10, 43, 46, 69, 85, 105, 127, 147, 183, 190, 195, 202], dtype='int64')

# %%
len(Rajasthan.index)
# Out:
# 12

# %%
mean_rank=(11+44+47+70+86+106+128+148+184+191+196+203)/12
Rajasthan_mean_rank=mean_rank
Rajasthan_mean_rank
# Out:
# 117.83333333333333

# %%
df11=dfs1[dfs1['State or Union Territory']== 'Haryana' ]
display(dfs1[dfs1["State or Union Territory"]=='Haryana' ])
# Out:
#           Cities Population(2011) Population(2001) State or Union Territory
# 25     Faridabad          1414050          1055938                  Haryana
# 56       Gurgaon           876824           173542                  Haryana
# 124       Rohtak           373133           286807                  Haryana
# 156      Panipat           294150           261740                  Haryana
# 162       Karnal           286974           210476                  Haryana
# 171      Sonipat           277053           214974                  Haryana
# 214  Yamunanagar           216677           189696                  Haryana
# 219    Panchkula           211355           140925                  Haryana
# 240      Bhiwani           196057           169531                  Haryana
# 242       Ambala           195153           139279                  Haryana
# 255        Sirsa           182534           160735                  Haryana

# %%
df111=df11.drop('State or Union Territory', inplace=True, axis=1) 
df111
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\263679859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df111=df11.drop('State or Union Territory', inplace=True, axis=1)

# %%
Haryana=df11
Haryana
# Out:
#           Cities Population(2011) Population(2001)
# 25     Faridabad          1414050          1055938
# 56       Gurgaon           876824           173542
# 124       Rohtak           373133           286807
# 156      Panipat           294150           261740
# 162       Karnal           286974           210476
# 171      Sonipat           277053           214974
# 214  Yamunanagar           216677           189696
# 219    Panchkula           211355           140925
# 240      Bhiwani           196057           169531
# 242       Ambala           195153           139279
# 255        Sirsa           182534           160735

# %%
Haryana.index
# Out:
# Int64Index([25, 56, 124, 156, 162, 171, 214, 219, 240, 242, 255], dtype='int64')

# %%
len(Haryana.index)
# Out:
# 11

# %%
mean_rank=(26+57+125+157+163+172+215+220+241+243+256)/11
Haryana_mean_rank=mean_rank
Haryana_mean_rank
# Out:
# 170.45454545454547

# %%
df12=dfs1[dfs1['State or Union Territory']== 'Jharkhand' ]
display(dfs1[dfs1["State or Union Territory"]=='Jharkhand' ])
# Out:
#           Cities Population(2011) Population(2001) State or Union Territory
# 33       Dhanbad          1162472          1065327                Jharkhand
# 38        Ranchi          1073427           847093                Jharkhand
# 72    Jamshedpur           631364           573096                Jharkhand
# 112       Bokaro           413934           393805                Jharkhand
# 204        Mango           223805           166125                Jharkhand
# 228      Deoghar           203123           112525                Jharkhand
# 251       Phusro           186139            83463                Jharkhand
# 280   Hazaribagh           153599           127243                Jharkhand
# 286      Giridih           143529          unknown                Jharkhand
# 295      Ramgarh           132441            73455                Jharkhand
# 301  Medininagar           120325          unknown                Jharkhand

# %%
df121=df12.drop('State or Union Territory', inplace=True, axis=1) 
df121
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\1183516623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df121=df12.drop('State or Union Territory', inplace=True, axis=1)

# %%
Jharkhand=df12
Jharkhand
# Out:
#           Cities Population(2011) Population(2001)
# 33       Dhanbad          1162472          1065327
# 38        Ranchi          1073427           847093
# 72    Jamshedpur           631364           573096
# 112       Bokaro           413934           393805
# 204        Mango           223805           166125
# 228      Deoghar           203123           112525
# 251       Phusro           186139            83463
# 280   Hazaribagh           153599           127243
# 286      Giridih           143529          unknown
# 295      Ramgarh           132441            73455
# 301  Medininagar           120325          unknown

# %%
Jharkhand.index
# Out:
# Int64Index([33, 38, 72, 112, 204, 228, 251, 280, 286, 295, 301], dtype='int64')

# %%
len(Jharkhand.index)
# Out:
# 11

# %%
mean_rank=(34+39+73+113+205+229+252+281+287+296+302)/11
Jharkhand_mean_rank=mean_rank
Jharkhand_mean_rank
# Out:
# 191.9090909090909

# %%
df13=dfs1[dfs1['State or Union Territory']== 'Telangana' ]
display(dfs1[dfs1["State or Union Territory"]=='Telangana' ])
# Out:
#                Cities Population(2011) Population(2001)  \
# 4           Hyderabad          6809970          3637483
# 61   Warangal[11][12]           830281           530636
# 150         Nizamabad           310467           288722
# 153           Khammam           305000           218689
# 179        Karimnagar           260899           205653
# 196    Ramagundam[24]           229644           236600
# 212      Secunderabad           217910           206102
# 276       Mahbubnagar           158000          unknown
# 307          Suryapet           115250            94585
# 308       Miryalaguda           109891            91395
#
#     State or Union Territory
# 4                  Telangana
# 61                 Telangana
# 150                Telangana
# 153                Telangana
# 179                Telangana
# 196                Telangana
# 212                Telangana
# 276                Telangana
# 307                Telangana
# 308                Telangana

# %%
df131=df13.drop('State or Union Territory', inplace=True, axis=1) 
df131
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\926456067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df131=df13.drop('State or Union Territory', inplace=True, axis=1)

# %%
Telangana=df13
Telangana
# Out:
#                Cities Population(2011) Population(2001)
# 4           Hyderabad          6809970          3637483
# 61   Warangal[11][12]           830281           530636
# 150         Nizamabad           310467           288722
# 153           Khammam           305000           218689
# 179        Karimnagar           260899           205653
# 196    Ramagundam[24]           229644           236600
# 212      Secunderabad           217910           206102
# 276       Mahbubnagar           158000          unknown
# 307          Suryapet           115250            94585
# 308       Miryalaguda           109891            91395

# %%
Telangana.index
# Out:
# Int64Index([4, 61, 150, 153, 179, 196, 212, 276, 307, 308], dtype='int64')

# %%
len(Telangana.index)
# Out:
# 10

# %%
mean_rank=(5+62+151+154+180+197+213+277+308+309)/10
Telangana_mean_rank=mean_rank
Telangana_mean_rank
# Out:
# 185.6

# %%
df14=dfs1[dfs1['State or Union Territory']== 'Assam' ]
display(dfs1[dfs1["State or Union Territory"]=='Assam' ])
# Out:
#          Cities Population(2011) Population(2001) State or Union Territory
# 48     Guwahati           957352           809895                    Assam
# 197     Silchar           229136           184105                    Assam
# 278   Dibrugarh           154296           137661                    Assam
# 279      Jorhat           153889           112026                    Assam
# 283      Nagaon           148496           123265                    Assam
# 290  Bongaigaon           139650           101213                    Assam
# 296    Tinsukia           126389           101957                    Assam
# 320      Tezpur           102505            83028                    Assam

# %%
df141=df14.drop('State or Union Territory', inplace=True, axis=1) 
df141
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\263351143.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df141=df14.drop('State or Union Territory', inplace=True, axis=1)

# %%
Assam=df14
Assam
# Out:
#          Cities Population(2011) Population(2001)
# 48     Guwahati           957352           809895
# 197     Silchar           229136           184105
# 278   Dibrugarh           154296           137661
# 279      Jorhat           153889           112026
# 283      Nagaon           148496           123265
# 290  Bongaigaon           139650           101213
# 296    Tinsukia           126389           101957
# 320      Tezpur           102505            83028

# %%
Assam.index
# Out:
# Int64Index([48, 197, 278, 279, 283, 290, 296, 320], dtype='int64')

# %%
len(Assam.index)
# Out:
# 8

# %%
mean_rank=(49+198+279+280+284+291+297+321)/8
Assam_mean_rank=mean_rank
Assam_mean_rank
# Out:
# 249.875

# %%
df15=dfs1[dfs1['State or Union Territory']== 'Delhi' ]
display(dfs1[dfs1["State or Union Territory"]=='Delhi' ])
# Out:
#                    Cities Population(2011) Population(2001)  \
# 2                   Delhi         11007835          9879172
# 167  Kirari Suleman Nagar           282598           153874
# 185             New Delhi           249998           302147
# 203         Karawal Nagar           224666           148549
# 225           Nangloi Jat           205596           150948
# 238  Bhalswa Jahangir Pur           197148           152339
# 258      Sultan Pur Majra           181554           164426
#
#     State or Union Territory
# 2                      Delhi
# 167                    Delhi
# 185                    Delhi
# 203                    Delhi
# 225                    Delhi
# 238                    Delhi
# 258                    Delhi

# %%
df151=df15.drop('State or Union Territory', inplace=True, axis=1) 
df151
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\1944905312.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df151=df15.drop('State or Union Territory', inplace=True, axis=1)

# %%
Delhi=df15
Delhi
# Out:
#                    Cities Population(2011) Population(2001)
# 2                   Delhi         11007835          9879172
# 167  Kirari Suleman Nagar           282598           153874
# 185             New Delhi           249998           302147
# 203         Karawal Nagar           224666           148549
# 225           Nangloi Jat           205596           150948
# 238  Bhalswa Jahangir Pur           197148           152339
# 258      Sultan Pur Majra           181554           164426

# %%
Delhi.index
# Out:
# Int64Index([2, 167, 185, 203, 225, 238, 258], dtype='int64')

# %%
len(Delhi.index)
# Out:
# 7

# %%
mean_rank=(3+168+186+204+226+239+259)/7
Delhi_mean_rank=mean_rank
Delhi_mean_rank
# Out:
# 183.57142857142858

# %%
df16=dfs1[dfs1['State or Union Territory']== 'Kerala' ]
display(dfs1[dfs1["State or Union Territory"]=='Kerala' ])
# Out:
#                  Cities Population(2011) Population(2001)  \
# 65   Thiruvananthapuram           752490           368618
# 76                Kochi           601574           596473
# 109           Kozhikode           432097           436556
# 132              Kollam           349033           361560
# 146            Thrissur           315596           317526
# 266           Alappuzha           174164           177029
# 267            Kottayam           172878           129894
#
#     State or Union Territory
# 65                    Kerala
# 76                    Kerala
# 109                   Kerala
# 132                   Kerala
# 146                   Kerala
# 266                   Kerala
# 267                   Kerala

# %%
df161=df16.drop('State or Union Territory', inplace=True, axis=1) 
df161
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2441173169.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df161=df16.drop('State or Union Territory', inplace=True, axis=1)

# %%
Kerala=df16
Kerala
# Out:
#                  Cities Population(2011) Population(2001)
# 65   Thiruvananthapuram           752490           368618
# 76                Kochi           601574           596473
# 109           Kozhikode           432097           436556
# 132              Kollam           349033           361560
# 146            Thrissur           315596           317526
# 266           Alappuzha           174164           177029
# 267            Kottayam           172878           129894

# %%
Kerala.index
# Out:
# Int64Index([65, 76, 109, 132, 146, 266, 267], dtype='int64')

# %%
len(Kerala.index)
# Out:
# 7

# %%
mean_rank=(69+80+113+136+150+270+271)/7
Kerala_mean_rank=mean_rank
Kerala_mean_rank
# Out:
# 155.57142857142858

# %%
df17=dfs1[dfs1['State or Union Territory']== 'Punjab' ]
display(dfs1[dfs1["State or Union Territory"]=='Punjab' ])
# Out:
#         Cities Population(2011) Population(2001) State or Union Territory
# 22    Ludhiana          1618879          1398467                   Punjab
# 34    Amritsar          1132383           966862                   Punjab
# 58   Jalandhar           862196           706043                   Punjab
# 115    Patiala           405164           303151                   Punjab
# 163   Bathinda           285813           217256                   Punjab
# 303   Phagwara           117966          unknown                   Punjab

# %%
df171=df17.drop('State or Union Territory', inplace=True, axis=1) 
df171
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2044003650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df171=df17.drop('State or Union Territory', inplace=True, axis=1)

# %%
Punjab=df17
Punjab
# Out:
#         Cities Population(2011) Population(2001)
# 22    Ludhiana          1618879          1398467
# 34    Amritsar          1132383           966862
# 58   Jalandhar           862196           706043
# 115    Patiala           405164           303151
# 163   Bathinda           285813           217256
# 303   Phagwara           117966          unknown

# %%
Punjab.index
# Out:
# Int64Index([22, 34, 58, 115, 163, 303], dtype='int64')

# %%
len(Punjab.index)
# Out:
# 6

# %%
mean_rank=(26+38+62+119+167+307)/6
Punjab_mean_rank=mean_rank
Punjab_mean_rank
# Out:
# 119.83333333333333

# %%
df18=dfs1[dfs1['State or Union Territory']== 'Chhattisgarh' ]
display(dfs1[dfs1["State or Union Territory"]=='Chhattisgarh'])
# Out:
#        Cities Population(2011) Population(2001) State or Union Territory
# 45     Raipur          1010087           605747             Chhattisgarh
# 73     Bhilai           625697           556366             Chhattisgarh
# 126     Korba           363210           315690             Chhattisgarh
# 137  Bilaspur           335761           296662             Chhattisgarh
# 173      Durg           268679           232517             Chhattisgarh
# 282   Raigarh           150019           115908             Chhattisgarh

# %%
df181=df18.drop('State or Union Territory', inplace=True, axis=1) 
df181
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\879058023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df181=df18.drop('State or Union Territory', inplace=True, axis=1)

# %%
Chhattisgarh=df18
Chhattisgarh
# Out:
#        Cities Population(2011) Population(2001)
# 45     Raipur          1010087           605747
# 73     Bhilai           625697           556366
# 126     Korba           363210           315690
# 137  Bilaspur           335761           296662
# 173      Durg           268679           232517
# 282   Raigarh           150019           115908

# %%
len(Chhattisgarh.index)
# Out:
# 6

# %%
mean_rank=(49+77+130+141+177+286)/6
Chhattisgarh_mean_rank=mean_rank
Chhattisgarh_mean_rank
# Out:
# 143.33333333333334

# %%
df19=dfs1[dfs1['State or Union Territory']== 'Odisha' ]
display(dfs1[dfs1["State or Union Territory"]=='Odisha'])
# Out:
#           Cities Population(2011) Population(2001) State or Union Territory
# 59   Bhubaneswar           837737           648032                   Odisha
# 74       Cuttack           606007           534654                   Odisha
# 82      Rourkela           552734           426354                   Odisha
# 128    Berhampur           355823           307792                   Odisha
# 138    Sambalpur           330106           274917                   Odisha
# 230         Puri           201026           152682                   Odisha

# %%
df191=df19.drop('State or Union Territory', inplace=True, axis=1) 
df191
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2722909456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df191=df19.drop('State or Union Territory', inplace=True, axis=1)

# %%
Odisha=df19
df19
# Out:
#           Cities Population(2011) Population(2001)
# 59   Bhubaneswar           837737           648032
# 74       Cuttack           606007           534654
# 82      Rourkela           552734           426354
# 128    Berhampur           355823           307792
# 138    Sambalpur           330106           274917
# 230         Puri           201026           152682

# %%
len(Odisha.index)
# Out:
# 6

# %%
Odisha.index
# Out:
# Int64Index([59, 74, 82, 128, 138, 230], dtype='int64')

# %%
mean_rank=(63+78+86+132+142+234)/6
Odisha_mean_rank=mean_rank
Odisha_mean_rank
# Out:
# 122.5

# %%
 df20=dfs1[dfs1['State or Union Territory']== 'Jammu and Kashmir' ]
display(dfs1[dfs1["State or Union Territory"]=='Jammu and Kashmir'])
# Out:
#         Cities Population(2011) Population(2001) State or Union Territory
# 31    Srinagar          1180570           898440        Jammu and Kashmir
# 94   Jammu[16]           503690           369959        Jammu and Kashmir
# 309   Anantnag           108505          unknown        Jammu and Kashmir

# %%
df201=df20.drop('State or Union Territory', inplace=True, axis=1) 
df201
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\4170251745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df201=df20.drop('State or Union Territory', inplace=True, axis=1)

# %%
Jammu_Kashmir=df20
Jammu_Kashmir
# Out:
#         Cities Population(2011) Population(2001)
# 31    Srinagar          1180570           898440
# 94   Jammu[16]           503690           369959
# 309   Anantnag           108505          unknown

# %%
Jammu_Kashmir.index
# Out:
# Int64Index([31, 94, 309], dtype='int64')

# %%
mean_rank=(35+98+313)/3
Jammu_Kashmir_mean_rank=mean_rank
Jammu_Kashmir_mean_rank
# Out:
# 148.66666666666666

# %%
 df21=dfs1[dfs1['State or Union Territory']== 'Puducherry' ]
display(dfs1[dfs1["State or Union Territory"]=='Puducherry'])
# Out:
#            Cities Population(2011) Population(2001) State or Union Territory
# 154  Uzhavarkarai           300028           217707               Puducherry
# 189   Pondicherry           241773           220749               Puducherry

# %%
df211=df21.drop('State or Union Territory', inplace=True, axis=1) 
df211
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\1538646386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df211=df21.drop('State or Union Territory', inplace=True, axis=1)

# %%
Puducherry=df21
Puducherry
# Out:
#            Cities Population(2011) Population(2001)
# 154  Uzhavarkarai           300028           217707
# 189   Pondicherry           241773           220749

# %%
Puducherry.index
# Out:
# Int64Index([154, 189], dtype='int64')

# %%
mean_rank=(154+189)/2
Puducherry_mean_rank=mean_rank
Puducherry_mean_rank
# Out:
# 171.5

# %%
 df22=dfs1[dfs1['State or Union Territory']== 'Uttarakhand' ]
display(dfs1[dfs1["State or Union Territory"]=='Uttarakhand'])
# Out:
#        Cities Population(2011) Population(2001) State or Union Territory
# 79   Dehradun           578420           426674              Uttarakhand
# 198  Haridwar           228832           175010              Uttarakhand

# %%
df221=df22.drop('State or Union Territory', inplace=True, axis=1) 
df221
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\3934221283.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df221=df22.drop('State or Union Territory', inplace=True, axis=1)

# %%
Uttarakhand=df22
df22
# Out:
#        Cities Population(2011) Population(2001)
# 79   Dehradun           578420           426674
# 198  Haridwar           228832           175010

# %%
Uttarakhand.index
# Out:
# Int64Index([79, 198], dtype='int64')

# %%
mean_rank=(79+198)/2
Uttarakhand_mean_rank=mean_rank
Uttarakhand_mean_rank
# Out:
# 138.5

# %%
ser= pd.value_counts(dfs1['State or Union Territory'])
ser1= ser[ser==1]
ser1
# Out:
# Tripura                           1
# Chandigarh                        1
# Mizoram                           1
# Manipur                           1
# Himachal Pradesh                  1
# Andaman and Nicobar Islands UT    1
# Sikkim                            1
# Goa                               1
# Name: State or Union Territory, dtype: int64

# %%
df23=dfs1.iloc[[46,116,158,173,268,287,322,323],:]
df23
# Out:
#             Cities Population(2011) Population(2001)  \
# 47      Chandigarh           960787           808515
# 117       Agartala           399688           271811
# 159         Aizawl           291822           228280
# 174         Imphal           264986           221492
# 269         Shimla           169578           142555
# 288     Port Blair           140572          unknown
# 323        Gangtok           100286            29354
# 324  Vasco Da Gama           100000          unknown
#
#            State or Union Territory
# 47                       Chandigarh
# 117                         Tripura
# 159                         Mizoram
# 174                         Manipur
# 269                Himachal Pradesh
# 288  Andaman and Nicobar Islands UT
# 323                          Sikkim
# 324                             Goa

# %%
df23.index
# Out:
# Int64Index([47, 117, 159, 174, 269, 288, 323, 324], dtype='int64')

# %%
len(df23.index)
# Out:
# 8

# %%
#To select rows whose column value equals a scalar, some_value, use ==:
#dfs1.loc[dfs1['State or Union Territory'] == 'Tripura'and"Chandigarh"]

# %%
# df[df['price'] < 20000]
# df[(df['price'] < 30000) & (df['mileage'] < 2000)]

# %%
mean_rank=(47+117+159+269+288+323+324)/7

Single_City_mean_rank=mean_rank
Single_City_mean_rank
# Out:
# 218.14285714285714

# %%
ping={'State or Union Territory':["Uttar_Pradesh ","Maharashtra ","Andhra_Pradesh","West_Bengal","Bihar","Tamil_Nadu","Madhya Pradesh","Karnataka ","Gujarat","Rajasthan","Haryana","Jharkhand","Telangana","Assam","Delhi","Kerala ","Punjab","Chhattisgarh","Odisha ","Jammu and Kashmir","Puducherry","Uttarakhand","Tripura","Chandigarh ","Mizoram ","Manipur","Himachal Pradesh","Andaman and Nicobar Islands UT","Sikkim ","Goa "]}


df65 = pd.DataFrame(ping)
df65.index +=1
df65.index
df65
# Out:
#           State or Union Territory
# 1                   Uttar_Pradesh
# 2                     Maharashtra
# 3                   Andhra_Pradesh
# 4                      West_Bengal
# 5                            Bihar
# 6                       Tamil_Nadu
# 7                   Madhya Pradesh
# 8                       Karnataka
# 9                          Gujarat
# 10                       Rajasthan
# 11                         Haryana
# 12                       Jharkhand
# 13                       Telangana
# 14                           Assam
# 15                           Delhi
# 16                         Kerala
# 17                          Punjab
# 18                    Chhattisgarh
# 19                         Odisha
# 20               Jammu and Kashmir
# 21                      Puducherry
# 22                     Uttarakhand
# 23                         Tripura
# 24                     Chandigarh
# 25                        Mizoram
# 26                         Manipur
# ...

# %%
df65.insert(0,"Mean_Rank", [140.7027027027027, 90.09375, 214.90322580645162,165.066666666666666,140.08,159.181818181812,161.05555555555554,142.14375,142.85714285714286,117.83333333333333,170.45454545454547,191.9090909090909,185.6,249.875,183.57142857142858,155.57142857142858,119.83333333333333,143.33333333333334,122.5,148.66666666666666,171.5,138.5,117,47,159,174,269,288,323,324], True)
df65
# Out:
#      Mean_Rank   Mean_Rank   Mean_Rank        State or Union Territory
# 1   140.702703  140.702703  140.702703                  Uttar_Pradesh
# 2    90.093750   90.093750   90.093750                    Maharashtra
# 3   214.903226  214.903226  214.903226                  Andhra_Pradesh
# 4   165.066667  165.066667  165.066667                     West_Bengal
# 5   140.080000  140.080000  140.080000                           Bihar
# 6   159.181818  159.181818  159.181818                      Tamil_Nadu
# 7   161.055556  161.055556  161.055556                  Madhya Pradesh
# 8   142.143750  142.143750  142.143750                      Karnataka
# 9   142.857143  142.857143  142.857143                         Gujarat
# 10  117.833333  117.833333  117.833333                       Rajasthan
# 11  170.454545  170.454545  170.454545                         Haryana
# 12  191.909091  191.909091  191.909091                       Jharkhand
# ...

# %%
df65.mean(axis = 0)
# Out:
# C:\Users\home\AppData\Local\Temp\ipykernel_18300\2771550293.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df65.mean(axis = 0)
# Mean_Rank    171.874426
# dtype: float64

# %% [markdown]
# ### Average of mean rank(171.874426)  of top 250 cities of india  is equal to Puducherry(171.500000)

# %%
Uttar Pradesh                   
Maharashtra                  
Andhra Pradesh                    
West Bengal                      
Bihar                             
Tamil Nadu                       
Madhya Pradesh                    
Karnataka                         
Gujarat                          
Rajasthan                        
Haryana                          
Jharkhand                        
Telangana                         
Assam                              
Delhi                              
Kerala                             
Punjab                             
Chhattisgarh                       
Odisha                             
Jammu and Kashmir                  
Puducherry                         
Uttarakhand                        
Tripura                         
Chandigarh                         
Mizoram                           
Manipur                           
Himachal Pradesh                  
Andaman and Nicobar Islands UT    

Sikkim                             
Goa
# Out:
#   File "C:\Users\home\AppData\Local\Temp\ipykernel_18300\722225896.py", line 1
#     Uttar Pradesh
#           ^
# SyntaxError: invalid syntax

# %%
df111=pd.DataFrame({"Mean Rank":[140.7027027027027, 90.09375, 214.90322580645162, 165.06666666666666,140.08,159.1818181818182,161.05555555555554,142.4375.142.85714285714286,117.83333333333333,170.45454545454547,191.9090909090909,185.6,249.875,183.57142857142858,155.57142857142858,119.83333333333333,143.33333333333334,122.5,148.66666666666666,171.5,138.5,117,47,159,174,269,288,323,324],
                'State or Union Territory':["Uttar_Pradesh ","Maharashtra ","Andhra_Pradesh","West_Bengal","Bihar","Tamil_Nadu","Madhya Pradesh","Karnataka ","Gujarat","Rajasthan","Haryana","Jharkhand","Telangana","Assam","Delhi","Kerala ","Punjab","Chhattisgarh","Odisha ","Jammu and Kashmir","Puducherry","Uttarakhand","Tripura","Chandigarh ","Mizoram ","Manipur","Himachal Pradesh","Andaman and Nicobar Islands UT","Sikkim ","Goa "],
})

# %%
mean_rank=pd.Series(['140.7027027027027', '90.09375', '214.90322580645162', '165.06666666666666',"140.08","159.1818181818182","161.05555555555554","142.4375"."142.85714285714286","117.83333333333333","170.45454545454547","191.9090909090909","185.6","249.875","183.57142857142858","155.57142857142858","119.83333333333333","143.33333333333334","122.5","148.66666666666666","171.5","138.5","117","47","159","174","269","288","323","324"],index=[0,1,2])

# %%
Mean_rank=pd.Series([140.7027027027027, 90.09375, 214.90322580645162, 165.06666666666666,140.08,159.1818181818182,161.05555555555554,142.4375.142.85714285714286,117.83333333333333,170.45454545454547,191.9090909090909,185.6,249.875,183.57142857142858,155.57142857142858,119.83333333333333,143.33333333333334,122.5,148.66666666666666,171.5,138.5,117,47,159,174,269,288,323,324],index=[0,1,2])
